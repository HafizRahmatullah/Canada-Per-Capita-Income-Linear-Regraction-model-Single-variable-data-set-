# %%
import pandas as py
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = py.read_csv("/home/rahmat/Downloads/canada_per_capita_income.xls")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
x1 = df['year'].T
x0 = np.ones(len(x1))
X = np.array([x0,x1]).T
Y = df['per capita income (US$)']


theta = np.zeros(X.shape[1])

# %%
plt.scatter(df['year'],Y)
plt.show()

# %%
x_transpose = X.T
x_inverse = np.linalg.pinv(x_transpose.dot(X))
x_transpose_y = x_transpose.dot(Y)
normal_equaction = x_inverse.dot(x_transpose_y)
plt.scatter(x1, Y)
plt.plot(x1,X.dot(normal_equaction) , label='Plots the line predicted by the normal equation solution ')
plt.title("year vs per capita income (US$)")
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, Y)
plt.scatter(x1, Y)
a = model.predict(X)
print('model cofecient :',model.coef_)
plt.plot(x1,a , label='Plots the line predicted by the LinearRegression model ')
plt.title("year vs per capita income (US$)")
plt.xlabel("year")
plt.ylabel("per capita income (US$)")
plt.legend()
plt.show()
# Out:
# model cofecient : [  0.         828.46507522]
